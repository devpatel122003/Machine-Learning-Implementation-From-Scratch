# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

file_path = 'Book1.xlsx' 
df = pd.read_excel(file_path, sheet_name='Sheet1')

df['trans_date_trans_time'] = pd.to_datetime(df['trans_date_trans_time'])
df['dob'] = pd.to_datetime(df['dob'])

df['trans_hour'] = df['trans_date_trans_time'].dt.hour
df['trans_day'] = df['trans_date_trans_time'].dt.day
df['trans_month'] = df['trans_date_trans_time'].dt.month
df['trans_year'] = df['trans_date_trans_time'].dt.year
df['age'] = (df['trans_date_trans_time'] - df['dob']).dt.days // 365

df['merch_zipcode'].fillna(df['merch_zipcode'].mode()[0], inplace=True)

sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))
sns.histplot(df['amt'], bins=50, kde=True)
plt.title('Distribution of Transaction Amounts')
plt.xlabel('Transaction Amount')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\devpa\AppData\Local\Temp\ipykernel_8728\3808460282.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['merch_zipcode'].fillna(df['merch_zipcode'].mode()[0], inplace=True)

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, y='category', order=df['category'].value_counts().index)
plt.title('Number of Transactions per Category')
plt.xlabel('Number of Transactions')
plt.ylabel('Category')
plt.show()

# %%
# # 3. Number of transactions per merchant
# plt.figure(figsize=(12, 6))
# sns.countplot(data=df, y='merchant', order=df['merchant'].value_counts().index)
# plt.title('Number of Transactions per Merchant')
# plt.xlabel('Number of Transactions')
# plt.ylabel('Merchant')
# plt.show()

# %%
df['trans_day_of_week'] = df['trans_date_trans_time'].dt.day_name()
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='trans_day_of_week', order=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
plt.title('Number of Transactions per Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Transactions')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='trans_hour')
plt.title('Number of Transactions per Hour of the Day')
plt.xlabel('Hour of the Day')
plt.ylabel('Number of Transactions')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['age'], bins=50, kde=True)
plt.title('Age Distribution of Cardholders')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='gender')
plt.title('Gender Distribution of Cardholders')
plt.xlabel('Gender')
plt.ylabel('Number of Cardholders')
plt.show()

# %%
# plt.figure(figsize=(10, 6))
# sns.histplot(df[df['is_fraud'] == 0]['amt'], bins=50, color='blue', label='Non-Fraudulent', kde=True)
# sns.histplot(df[df['is_fraud'] == 1]['amt'], bins=50, color='red', label='Fraudulent', kde=True)
# plt.title('Distribution of Transaction Amounts (Fraudulent vs. Non-Fraudulent)')
# plt.xlabel('Transaction Amount')
# plt.ylabel('Frequency')
# plt.legend()
# plt.show()

# %%
# plt.figure(figsize=(8, 6))
# sns.countplot(data=df, x='is_fraud')
# plt.title('Number of Fraudulent vs. Non-Fraudulent Transactions')
# plt.xlabel('Is Fraud')
# plt.ylabel('Number of Transactions')
# plt.xticks([0, 1], ['Non-Fraudulent', 'Fraudulent'])
# plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(data=df, x='category', y='amt')
plt.title('Distribution of Transaction Amounts per Category')
plt.xlabel('Category')
plt.ylabel('Transaction Amount')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(data=df, x='merchant', y='amt')
plt.title('Distribution of Transaction Amounts per Merchant')
plt.xlabel('Merchant')
plt.ylabel('Transaction Amount')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.countplot(data=df, y='state', order=df['state'].value_counts().index)
plt.title('Number of Transactions per State')
plt.xlabel('Number of Transactions')
plt.ylabel('State')
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.countplot(data=df, y='city', order=df['city'].value_counts().index)
plt.title('Number of Transactions per City')
plt.xlabel('Number of Transactions')
plt.ylabel('City')
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.barplot(data=df, x='category', y='amt', estimator=lambda x: x.mean())
plt.title('Average Transaction Amount per Category')
plt.xlabel('Category')
plt.ylabel('Average Transaction Amount')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.barplot(data=df, x='merchant', y='amt', estimator=lambda x: x.mean())
plt.title('Average Transaction Amount per Merchant')
plt.xlabel('Merchant')
plt.ylabel('Average Transaction Amount')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.countplot(data=df, y='job', order=df['job'].value_counts().index)
plt.title('Number of Transactions per Job Title')
plt.xlabel('Number of Transactions')
plt.ylabel('Job Title')
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.barplot(data=df, x='job', y='amt', estimator=lambda x: x.mean())
plt.title('Average Transaction Amount per Job Title')
plt.xlabel('Job Title')
plt.ylabel('Average Transaction Amount')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['city_pop'], bins=50, kde=True)
plt.title('Number of Transactions per City Population')
plt.xlabel('City Population')
plt.ylabel('Number of Transactions')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='merch_long', y='merch_lat', hue='is_fraud', palette={0: 'blue', 1: 'red'}, alpha=0.6)
plt.title('Distribution of Merchant Latitude and Longitude')
plt.xlabel('Merchant Longitude')
plt.ylabel('Merchant Latitude')
plt.legend(title='Is Fraud', labels=['Non-Fraudulent', 'Fraudulent'])
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='long', y='lat', hue='is_fraud', palette={0: 'blue', 1: 'red'}, alpha=0.6)
plt.title('Distribution of Cardholder Latitude and Longitude')
plt.xlabel('Cardholder Longitude')
plt.ylabel('Cardholder Latitude')
plt.legend(title='Is Fraud', labels=['Non-Fraudulent', 'Fraudulent'])
plt.show()
